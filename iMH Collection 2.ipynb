# %%
class Test:
    def main(self):
        stra = "do"
        
        strb = Test.method(stra)
        print(stra,strb)
        
    def method(stra):
        stra = "good"
        return stra
        
m = Test()

m.main()
# Out:
# do good

# %%
def kitchen():
    pass

def hall(color):
    cHall = "yellow"
    print("You're In Hall")
    data.append(cHall)
    
    x = input("ENTER ROOM YOU WANT TO ENTER: ")
    if x =="kitchen":
        kitchen()
    
    
def bedroom():
    pass

def bathroom():
    pass

data = ["black"]
color = "black"

hall(color)

print(data)
# Out:
# You're In Hall
# ENTER ROOM YOU WANT TO ENTER: kitchen
# ['black', 'yellow']

# %%
d = {"kitchen":"red", "bedroom":"yellow", "bathroom":"orange","hall":"blue"}
data = []
while True:
    if input("Do You Want To Continue") == "Yes":
        x = input("U R IN:")
        data.append(d[x])
    else:
        print(data)
        break
# Out:
# Do You Want To Continueyes
# []

# %%
import re

txt='MUNAF MUBARAK HAJIR 9820227065 '

re1='.*?'	# Non-greedy match on filler
re2='(9820227065)'	# Integer Number 1

rg = re.compile(re1+re2,re.IGNORECASE|re.DOTALL)
m = rg.search(txt)
if m:
    int1=m.group(1)
    print(int1)
# Out:
# 9820227065

# %%
import bs4 as bs
import urllib.request

sauce = urllib.request.urlopen("https://www.marham.pk/forum/thread/4493/selective-mutism").read()
# print(sauce)

soup = bs.BeautifulSoup(sauce,'html5lib')

print(soup)
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US"><head>
# 	<meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# 	<meta content="MARHAM" name="author"/>
# 			<meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#     <meta content="width=device-width, initial-scale=1" name="viewport"/>
#     	<meta content="XgJiSW7pddl2zEdA-ZMm0bZGHchxcZG_slPP0x0RHyk" name="google-site-verification"/>
# 	<meta content="THq7cH0As4Cs_zL57wfJpkubHI8FtJ1jgJbzTGTLY8Q" name="google-site-verification"/>
# 	    <meta content="Psychologist Question - Aoa, my 4 year old son is a shy child in public. He is active and energetic at home. He speaks just about fine and has a very... " name="description"/>
# 	<meta content="https://www.marham.pk/forum/thread/4493/selective-mutism" property="og:url"/>
# 	<meta content="website" property="og:type"/>
# 	<meta content="Selective Mutism - Aoa, my 4 year o - Ask a doctor online" property="og:title"/>
# ...

# %%
print(soup.find_all('p'))
# Out:
# [<p class="patient-details" itemprop="address" itemscope="" itemtype="https://schema.org/PostalAddress">Asking for Other, Female, 32 years old, <span itemprop="addressLocality">Karachi, Pakistan</span></p>, <p itemprop="description">Aoa, my 4 year old son is a shy child in public. He is active and energetic at home. He speaks just about fine and has a very good intellectual sense. It has been almost 4 months since I have enrolled him in a school. He enjoys everything about his school but doesn't talk or answer his teachers. I have tried to encourage him and his teachers into help him become comfortable to share his stories but the school management is insisting that my kid doesn't know how to talk at all. I have urged the school management that my kid has been reciting duas for Entering and exiting the washroom as well as the Dua before sleep since he was only 2.5 years old. He talks just fine like his age children do. Should I consult with a speech therapist in this regard because i
# ...

# %%
l = []

for para in soup.find_all('p'):
    l.append(para.string)

# %%
l
# Out:
# [None,
#  "Aoa, my 4 year old son is a shy child in public. He is active and energetic at home. He speaks just about fine and has a very good intellectual sense. It has been almost 4 months since I have enrolled him in a school. He enjoys everything about his school but doesn't talk or answer his teachers. I have tried to encourage him and his teachers into help him become comfortable to share his stories but the school management is insisting that my kid doesn't know how to talk at all. I have urged the school management that my kid has been reciting duas for Entering and exiting the washroom as well as the Dua before sleep since he was only 2.5 years old. He talks just fine like his age children do. Should I consult with a speech therapist in this regard because in my opinion my child has slipped into selective mutism and the school needs to do something about this rather than becoming more hostile towards my child.",
#  None,
#  None,
#  '\n            ',
# ...

# %%
l[-2]
# Out:
# 'As you mentioned child did not have any speech issues at home, So no need\nto see a speech therapist but definitely need to see a child psychologist.\nAs at that stage first need to explore the cause of selective mutism at\nschool and to fix the issues at school, trained the child to handle the\ndifficult situations which required Structured Play therapy.'

# %%
sauce2 = urllib.request.urlopen("https://www.marham.pk/forum").read()

soup2 = bs.BeautifulSoup(sauce2 , "html5lib")

print(soup2.find_all('a'))
# Out:
# [<a href="https://www.marham.pk">Home</a>, <a href="https://www.marham.pk/contact">Contact</a>, <a id="topbar-selected-city">City</a>, <a class="topbar-city-list" onclick="updateCookie($(this).attr('orgval'))" orgval="lahore">Lahore</a>, <a class="topbar-city-list" onclick="updateCookie($(this).attr('orgval'))" orgval="karachi">Karachi</a>, <a class="topbar-city-list" onclick="updateCookie($(this).attr('orgval'))" orgval="islamabad">Islamabad</a>, <a class="topbar-city-list" onclick="updateCookie($(this).attr('orgval'))" orgval="multan">Multan</a>, <a class="topbar-city-list" onclick="updateCookie($(this).attr('orgval'))" orgval="faisalabad">Faisalabad</a>, <a class="topbar-city-list" onclick="updateCookie($(this).attr('orgval'))" orgval="rawalpindi">Rawalpindi</a>, <a class="topbar-city-list" onclick="updateCookie($(this).attr('orgval'))" orgval="sargodha">Sargodha</a>, <a class="topbar-city-list" onclick="updateCookie($(this).attr('orgval'))" orgval="rahim yar khan">Rahim Yar Khan<
# ...

# %%
for url in soup2.find_all('a'):
    print(url.get('href'))
# Out:
# https://www.marham.pk
# https://www.marham.pk/contact
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.marham.pk/register/doctor
# https://www.facebook.com/groups/marham.pk/
# https://twitter.com/marhampk
# https://www.instagram.com/marhampk/
# tel:+92.42.32591427
# mailto:info@marham.pk
# https://www.marham.pk/register/doctor
# https://www.marham.pk
# https://www.marham.pk
# https://www.marham.pk/forum
# https://www.marham.pk/find-a-doctor
# https://www.marham.pk/find-a-doctor
# https://www.marham.pk/find-a-surgeon
# https://www.marham.pk/services
# https://www.marham.pk/diseases
# https://www.marham.pk/free-medical-services
# https://www.marham.pk/healthblog/
# #
# https://www.marham.pk/marham-for-patients
# https://www.marham.pk/marham-for-doctors
# https://www.marham.pk/about
# https://www.marham.pk/publications
# #
# https://www.marham.pk/register
# ...

# %%
newl = []

for div in soup2.find_all('div',class_='thread-details'):
    newl.append(div)
    
a = newl[0]

# %%
link = []
for url in a('a'):
    link.append(url.get('href'))

# %%
link[0]
# Out:
# 'https://www.marham.pk/forum/thread/4494/skin'

# %%
#lazy bartender

from collections import Counter 
drinks = []

no = int(input("Enter No Of Possible Drinks: "))
l = [(i) for i in range(1,no+1)]

c = int(input("No Of Fixed Customers: "))
i=1

count = []

while i < c+1 :
    
    print("Customer {} Drinks :".format(i))
    n = int(input("How Much Drink: "))
    
    for j in range(n):
        
        temp = int(input("ENTER DRINK {}:".format(j)))
        
        if temp <= no:
            count.append(temp)
        elif temp >= no:
            temp = int(input("ENTER DRINK {} AGAIN:".format(j)))
            if temp <= no:
                count.append(temp)
            else:
                print("You're Entering wrong drink")
                break
        
    i+=1    
    

word_counter = Counter(count)
top = word_counter.most_common(3) 
print(top)
# Out:
# Enter No Of Possible Drinks: 9
# No Of Fixed Customers: 5
# Customer 1 Drinks :
# How Much Drink: 5
# ENTER DRINK 0:3
# ENTER DRINK 1:7
# ENTER DRINK 2:5
# ENTER DRINK 3:2
# ENTER DRINK 4:9
# Customer 2 Drinks :
# How Much Drink: 1
# ENTER DRINK 0:5
# Customer 3 Drinks :
# How Much Drink: 2
# ENTER DRINK 0:2
# ENTER DRINK 1:3
# Customer 4 Drinks :
# How Much Drink: 1
# ENTER DRINK 0:4
# Customer 5 Drinks :
# How Much Drink: 6
# ENTER DRINK 0:3
# ENTER DRINK 1:4
# ENTER DRINK 2:3
# ENTER DRINK 3:5
# ENTER DRINK 4:7
# ENTER DRINK 5:4
# [(3, 4), (5, 3), (4, 3)]

# %%
for i in top:
    print(i[0])
# Out:
# 3
# 5
# 4

# %%
#morning assembly
task = int(input("Enter Number Of Task: "))
n_task = int(input("Enter Number Of Task Completed: "))
task_completed = []
remain = []

for i in range(n_task):
    task_completed.append(int(input()))

for i in range(1,task+1):
    if i in task_completed:
        pass
    else:
        remain.append(i)

print(remain)
# Out:
# Enter Number Of Task: 15
# Enter Number Of Task Completed: 6
# 2
# 5
# 6
# 7
# 9
# 4
# [1, 3, 8, 10, 11, 12, 13, 14, 15]

# %%
#beautiful sequence
n = int(input("Enter N Value: "))

l = []
l.append(n)
for i in range(n-1,0,-1):
    if n%i == 0:
        l.append(i)
        n=i
        
print(l[-1:0:-1])
# Out:
# Enter N Value: 24
# [1, 3, 6, 12]

# %%
l
# Out:
# [24, 12, 6, 3, 1]

# %%
n = int(input())
data = []
result = []
for _ in range(n):
    data.append(int(input()))

for i in range(0,n):
    maxi = max(data[i+1%n:])
    mini = min(data[i+1%n:])
    
    diff = maxi - mini

    if diff <= 1:
        print(data[i+1:])
        break
    
                
            
        
        
        
#5 45 5 6 7 8  8 8 7 6
# Out:
# 5
# 1
# 2
# 3
# 3
# 2
# [2, 3, 3, 2]

# %%
data
# Out:
# [1, 2, 3, 3, 2]

# %%
def getMagicGroups():
    
    groups = []
    for n1 in range(1,10):
        for n2 in range(1,10):
            for n3 in range(1,10):
                if n1 != n2 and n1 != n3 and n2 != n3 and n1 + n2 + n3 == 15:
                    a = sorted([n1,n2,n3])
                    if a not in groups: groups.append(a)
 
    return sorted(groups)

counts = {}
for group in getMagicGroups():
      for n in group:
        counts[n] = counts.get(n, 0) + 1

for k, v in sorted(counts.items()):
    print('{0}: {1}'.format(k, v))
# Out:
# 1: 2
# 2: 3
# 3: 2
# 4: 3
# 5: 4
# 6: 3
# 7: 2
# 8: 3
# 9: 2

# %%
# t = int(input())
# for i in range(t):
n = int(input())
arr = [int(x) for x in input().split()]
l = 0
for j in range(n):
    
    maxi = arr[j]
    mini = arr[j]
    l1 = 1
    for k in range(j+1,n):
        
        if arr[k] > maxi and arr[k] > mini:
            if arr[k]-mini <= 1:
                l1 += 1
                maxi = arr[k]
            else:
                break
        elif arr[k] < maxi and arr[k] < mini:
            if maxi-arr[k] <= 1:
                l1 += 1
                mini = arr[k]
            else:
                break
        else:
            l1 += 1
    if l1>l:
        l = l1
print(l)
# Out:
# 11
# 54556788876
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-dcf1ee2c8889> in <module>()
#      11     for k in range(j+1,n):
#      12
# ---> 13         if arr[k] > maxi and arr[k] > mini:
#      14             if arr[k]-mini <= 1:
#      15                 l1 += 1
#
# IndexError: list index out of range

# %%
# n = int(input())
a = [5,4,5,5,6,7,8,8,8,7,6]

results = []


for i in range(len(a)):
    l = 0
    for j in range(i,len(a)):
        if abs(a[i % len(a)-1] - a[i+1 % len(a)-1] <= 1):
            l+=1
            
        else:
            break
            
        if l>0:
            results.append(i)
            
if results:
    tmp = max(results,key = lambda x:x[1])#,key = lambda x:x[1]
    print(a[tmp[0],sum(tmp)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-d5b57081dd1b> in <module>()
#      18
#      19 if results:
# ---> 20     tmp = max(results,key = lambda x:x[1])#,key = lambda x:x[1]
#      21     print(a[tmp[0],sum(tmp)])
#
# <ipython-input-30-d5b57081dd1b> in <lambda>(x)
#      18
#      19 if results:
# ---> 20     tmp = max(results,key = lambda x:x[1])#,key = lambda x:x[1]
#      21     print(a[tmp[0],sum(tmp)])
#
# TypeError: 'int' object is not subscriptable

# %%
import numpy as np
a = [5,4,5,5,6,7,8,8,8,7,6]
max_diff = 1
sub_arrays = [x for x in [a[i:j] for i in range(len(a)) for j in range(i+1, len(a))] if (max(x)-min(x) <= max_diff)]
max_sub_array = sub_arrays[np.argmax([len(sa) for sa in sub_arrays])]

# %%
max_sub_array
# Out:
# [7, 8, 8, 8, 7]

# %%
l = ["a","b","a"]
result = []
#a,b = xoxo
#b =x
#a =o
#b,a = xoxo
i = 0
a = 0
b = 0
while True:
        
    if i == len(l)+1:
        break
        
    else:
        if i == len(l):
            
        elif a == 1:
            if l[i] == "b":
                result.append("xoxo")
                a = 0
                i += 1
                
            else : 
                result.append("o")
                
        elif b == 1:
            if l[i] == "a":
                result.append("xoxo")
                b=0
                i+=1
            else : 
                result.append("x")    
                
        elif l[i] == "a":
            a = 1
            i += 1
            
        elif l[i] == "b":
            b = 1
            i += 1
            
        
            
print(result)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-362a3cb37c54> in <module>()
#      15     else:
#      16         if a == 1:
# ---> 17             if l[i] == "b":
#      18                 result.append("xoxo")
#      19                 a = 0
#
# IndexError: list index out of range

# %%
import re
def newStyleFormatting(s):
    return "%".join([re.sub("%([bcdeEfFgGnosxX])","{}",S) for S in s.split("%%")])

newStyleFormatting("We expect the %f%% growth this week")
# Out:
# 'We expect the {}% growth this week'

# %%
def listsConcatenation(lst1, lst2):
    res = lst1
    res.extend(lst2)
    return res
lst1 = [2, 2, 1]
lst2 = [10, 11]
listsConcatenation(lst1,lst2)
# Out:
# [2, 2, 1, 10, 11]

# %%
def twoteams(students):
    
    return sum(students[::2])-sum(students[1::2])
lst=[1, 11, 13, 6, 14] 
twoteams(lst)
# Out:
# 11

# %%
def removeTasks(k, toDo):
    del toDo[k - 1:k]
    return toDo

toDo=[1237, 2847, 27485, 2947, 1, 247, 374827, 22]
k = 3

removeTasks(k,toDo)
# Out:
# [1237, 2847, 2947, 1, 247, 374827, 22]

# %%
def printList(lst):
    return "This is your list: {}".format(lst)

lst = [1,2,3,4,5]

printList(lst)
# Out:
# 'This is your list: [1, 2, 3, 4, 5]'

# %%
k=3
toDo=[1237, 2847, 27485, 2947, 1, 247, 374827, 22]
toDo[k - 1::k]
# Out:
# [27485, 247]

# %%
n = 6
l = [1,0,8,6,4,2]
j = 0

tot2 = 0
result = 0

while True:
    
    if (n-j)<2:
        break
        
    elif result==0 :
        result = sum(l[j:j+3])
        j+=1
        
    else:
        tot2 = sum(l[j:j+3])
        
        result = tot2<result and result or tot2
        j+=1

        
print(result)
# Out:
# 18

# %%
import os

x = os.system("ls/dev/ttyUSB0")

if x==0:
    print("Connected")
    
else:
    print("dis")
# Out:
# dis

# %%
import serial

# %%
ser = serial.Serial('/ttyUSB0')
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# <ipython-input-4-2eb5315b4ea2> in <module>()
# ----> 1 ser = serial.Serial('/ttyUSB0')
#
# D:\Anaconda\lib\site-packages\serial\serialwin32.py in __init__(self, *args, **kwargs)
#      29         self._overlapped_read = None
#      30         self._overlapped_write = None
# ---> 31         super(Serial, self).__init__(*args, **kwargs)
#      32
#      33     def open(self):
#
# D:\Anaconda\lib\site-packages\serial\serialutil.py in __init__(self, port, baudrate, bytesize, parity, stopbits, timeout, xonxoff, rtscts, write_timeout, dsrdtr, inter_byte_timeout, exclusive, **kwargs)
#     238
#     239         if port is not None:
# --> 240             self.open()
#     241
#     242     #  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#
# D:\Anaconda\lib\site-packages\serial\serialwin32.py in open(self)
# ...

# %%
def decToBin(x):
    return int(bin(x)[2:])

def revNum(y):
    reversed_num = str(y)[::-1]
    return int(reversed_num)

value = int(input("Enter Decimal Number: "))
bin_value = decToBin(value)

if bin_value == revNum(bin_value):
    print("Binary Number Of Value Is Palindrome")
    
else:
    print("Not Palindrome")
# Out:
# Enter Decimal Number: 3
# Binary Number Of Value Is Palindrome

# %%
def revNum(y):
    reverse = 0
    while y > 0:
        Reminder = y %10
        reverse = (reverse *10) + Reminder
        y = y //10
        
    return y
# Out:
# 10
